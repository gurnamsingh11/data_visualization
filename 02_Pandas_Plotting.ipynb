# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv("Data_Analysis/Data/titanic.csv")
titanic["age"] = pd.to_numeric(titanic["age"], errors="coerce")

# %%
houses = pd.read_csv("Data_Analysis/Data/kc_house_data.csv", parse_dates=["date"])

# %%
ufos = pd.read_csv("Data_Analysis/Data/nuforc_reports.csv",
                   on_bad_lines='skip',
                   delimiter="\t")

# %%
# ufos = pd.read_csv("Data_Analysis/Data/nuforc_reports.csv")

# %%
# ufos = pd.read_csv("Data_Analysis/Data/nuforc_reports.csv",header = None, delimiter="\t", quoting=csv.QUOTE_NONE, encoding='utf-8')

# %% [markdown]
# ### Bar

# %%
titanic.sex.value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
titanic.sex.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %%
houses[["sqft_living", "sqft_lot"]].sort_values("sqft_living", ascending=False).head(10)
# Out:
#        sqft_living  sqft_lot
# 12777        13540    307752
# 7252         12050     27600
# 3914         10040     37325
# 9254          9890     31374
# 8092          9640     13068
# 4411          9200     35069
# 14556         8670     64033
# 18302         8020     21738
# 1164          8010     45517
# 1448          8000     23985

# %%
houses[["sqft_living", "sqft_lot"]].sort_values("sqft_living", ascending=False).head(10).plot(kind="bar")
# Out:
# <Axes: >

# %%
houses[["sqft_living", "sqft_lot", "price"]].sort_values("sqft_living", ascending=False).head(10).plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# ### Adding Labels and Titles

# %%
titanic.sex.value_counts().plot(kind="bar", title="Sex Breakdown on Titanic")
# Out:
# <Axes: title={'center': 'Sex Breakdown on Titanic'}, xlabel='sex'>

# %%
titanic.sex.value_counts().plot(kind="bar")
plt.title("My Title", loc="right", fontsize=20)
plt.xlabel("X Label")
plt.ylabel("Y Label")
# Out:
# Text(0, 0.5, 'Y Label')

# %% [markdown]
# ### Using rename() when Plotting

# %%
ufos["month"] = ufos["date_time"].dt.month
ufos["year"] = ufos["date_time"].dt.year

# %%
sightings = ufos.month.value_counts().sort_index()
sightings.plot(
    kind="bar", 
    title="UFO Sightings By Month", 
    xlabel="Month",
    ylabel="Num Sightings",
    fontsize="10")

# %% [markdown]
# ![1.png](Data_Analysis/Images/1.png)

# %%
sightings = ufos.month.value_counts().sort_index()
sightings.plot(
    kind="bar", 
    title="UFO Sightings By Month", 
    fontsize="10")
plt.xlabel("Month", fontsize=24, color="olive")
plt.ylabel("Num Sightings", fontsize=24)

# %% [markdown]
# ![2.png](Data_Analysis/Images/2.png)

# %%
sightings = ufos.month.value_counts().sort_index()
sightings.plot(
    kind="bar", 
    title="UFO Sightings By Month", 
    fontsize="10")
plt.xlabel("Month", fontsize=24, color="olive")
plt.ylabel("Num Sightings", fontsize=24)

# %% [markdown]
# ![3.png](Data_Analysis/Images/3.png)

# %%
sightings.rename(months_dict).plot(
    kind="bar", 
    title="UFO Sightings By Month", 
    fontsize="20")
plt.xlabel("Month", fontsize=24, color="olive")
plt.ylabel("Num Sightings", fontsize=24)

# %% [markdown]
# ![4.png](Data_Analysis/Images/4.png)

# %% [markdown]
# ### Closer Look at Bar Plots

# %%
salaries = pd.read_csv("Data_Analysis/Data/Salaries.csv", low_memory=False)

# %%
salaries.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
salaries["BasePay"] = pd.to_numeric(salaries["BasePay"], errors="coerce").fillna(0)
salaries["OvertimePay"] = pd.to_numeric(salaries["OvertimePay"], errors="coerce").fillna(0)
salaries["OtherPay"] = pd.to_numeric(salaries["OtherPay"], errors="coerce").fillna(0)

# %%
salaries.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25      NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60      NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90      NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
df = salaries[["EmployeeName", "BasePay", "OvertimePay", "OtherPay"]]
df.head()
# Out:
#         EmployeeName    BasePay  OvertimePay   OtherPay
# 0     NATHANIEL FORD  167411.18         0.00  400184.25
# 1       GARY JIMENEZ  155966.02    245131.88  137811.38
# 2     ALBERT PARDINI  212739.13    106088.18   16452.60
# 3  CHRISTOPHER CHONG   77916.00     56120.71  198306.90
# 4    PATRICK GARDNER  134401.60      9737.00  182234.59

# %%
df.set_index("EmployeeName", inplace=True)

# %%
df.head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
df.head(10).plot(kind="bar", stacked=True)
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
df["BasePay"].sort_values(ascending=False).head(5).plot(kind="bar")
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
df["BasePay"].sort_values(ascending=False).head(5).plot.bar(color="red", title="Highest Paid SF Employees")
# Out:
# <Axes: title={'center': 'Highest Paid SF Employees'}, xlabel='EmployeeName'>

# %%
df["BasePay"].sort_values(ascending=False).head(5).plot.barh(color="red", title="Highest Paid SF Employees")
# Out:
# <Axes: title={'center': 'Highest Paid SF Employees'}, ylabel='EmployeeName'>

# %%
df.sort_values("OvertimePay", ascending=False).head().plot(kind="barh", stacked=True)
plt.xlabel("Dollars $")
# Out:
# Text(0.5, 0, 'Dollars $')

# %% [markdown]
# ### Exercise Pandas Plotting 1

# %%
df = pd.read_csv("Data_Analysis/Data/billboard_charts.csv", parse_dates=["date"])

# %%
df.head()
# Out:
#         date  rank           song                         artist  last-week  \
# 0 2021-11-06     1     Easy On Me                          Adele        1.0
# 1 2021-11-06     2           Stay  The Kid LAROI & Justin Bieber        2.0
# 2 2021-11-06     3  Industry Baby        Lil Nas X & Jack Harlow        3.0
# 3 2021-11-06     4     Fancy Like                   Walker Hayes        4.0
# 4 2021-11-06     5     Bad Habits                     Ed Sheeran        5.0
#
#    peak-rank  weeks-on-board
# 0          1               3
# 1          1              16
# 2          1              14
# 3          3              19
# 4          2              18

# %%
df["week"] = df["date"].dt.dayofweek

# %%
top_10 = df[df["rank"]==1]["artist"].value_counts().head(10)

# %%
plt.style.use("ggplot")

# %%
top_10.plot(kind="barh",
            title="Artists With Most Week #1",
            figsize=(8,6),
            edgecolor="black",
            linewidth=3)
plt.xlabel("Weeks at #1")
# Out:
# Text(0.5, 0, 'Weeks at #1')

# %% [markdown]
# ### Pandas Histograms

# %%
salaries = pd.read_csv("Data_Analysis/Data/Salaries.csv", low_memory=False)

# %%
salaries["BasePay"] = pd.to_numeric(salaries["BasePay"], errors="coerce").fillna(0)

# %%
salaries["BasePay"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
salaries["BasePay"].plot(kind="hist", bins=200, color="purple")
# Out:
# <Axes: ylabel='Frequency'>

# %%
salaries["BasePay"] = pd.to_numeric(salaries["BasePay"], errors="coerce").fillna(0)
salaries["OvertimePay"] = pd.to_numeric(salaries["OvertimePay"], errors="coerce").fillna(0)
salaries["OtherPay"] = pd.to_numeric(salaries["OtherPay"], errors="coerce").fillna(0)
df = salaries[["EmployeeName", "BasePay", "OvertimePay", "OtherPay"]]
df.index = df["EmployeeName"]
df.drop("EmployeeName", axis=1, inplace=True)

# %%
df.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind="hist", bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'BasePay'}>,
#         <Axes: title={'center': 'OvertimePay'}>],
#        [<Axes: title={'center': 'OtherPay'}>, <Axes: >]], dtype=object)

# %% [markdown]
# ### Box Plots

# %%
df.plot(kind="box")
# Out:
# <Axes: >

# %%
houses = pd.read_csv("Data_Analysis/Data/kc_house_data.csv", parse_dates=['date'])

# %%
houses.bedrooms.plot(kind="box")
# Out:
# <Axes: >

# %%
houses.bedrooms.plot(kind="box", showfliers=False)
# Out:
# <Axes: >

# %%
houses[["bedrooms", "bathrooms"]].plot(kind="box", showfliers=False)
# Out:
# <Axes: >

# %% [markdown]
# ### Pandas Line Plots

# %%
titanic.plot()
# Out:
# <Axes: >

# %%
houses["year"] = houses["date"].dt.year
houses.year
# Out:
# 0        2014
# 1        2014
# 2        2015
# 3        2014
# 4        2015
#          ...
# 21608    2014
# 21609    2015
# 21610    2014
# 21611    2015
# 21612    2014
# Name: year, Length: 21613, dtype: int32

# %%
years = pd.Series(range(2000, 2025))  # Years from 2000 to 2024

# Generate some random data corresponding to the years
data = pd.Series(np.random.randint(50, 100, size=len(years)))

# %%
data.plot(kind="line", color="olive", linewidth=10, linestyle=":")
# Out:
# <Axes: >

# %%
df
# Out:
#                      BasePay  OvertimePay   OtherPay
# EmployeeName
# NATHANIEL FORD     167411.18         0.00  400184.25
# GARY JIMENEZ       155966.02    245131.88  137811.38
# ALBERT PARDINI     212739.13    106088.18   16452.60
# CHRISTOPHER CHONG   77916.00     56120.71  198306.90
# PATRICK GARDNER    134401.60      9737.00  182234.59
# ...                      ...          ...        ...
# Roy I Tillery           0.00         0.00       0.00
# Not provided            0.00         0.00       0.00
# Not provided            0.00         0.00       0.00
# Not provided            0.00         0.00       0.00
# Joe Lopez               0.00         0.00    -618.13
#
# [148654 rows x 3 columns]

# %%
df.plot.line()
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
houses.plot.line()
# Out:
# <Axes: >
# Error in callback <function _draw_all_if_interactive at 0x7f1c1f73c550> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/matplotlib/pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
# ...

# %%
houses.plot.line(y="price")
# Out:
# <Axes: >

# %%
houses.plot.line(y="price", x="bedrooms")
# Out:
# <Axes: xlabel='bedrooms'>

# %% [markdown]
# ### Exercise

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
billboard = pd.read_csv("Data_Analysis/Data/billboard_charts.csv",
                        parse_dates=["date"])

# %%
billboard.head()
# Out:
#         date  rank           song                         artist  last-week  \
# 0 2021-11-06     1     Easy On Me                          Adele        1.0
# 1 2021-11-06     2           Stay  The Kid LAROI & Justin Bieber        2.0
# 2 2021-11-06     3  Industry Baby        Lil Nas X & Jack Harlow        3.0
# 3 2021-11-06     4     Fancy Like                   Walker Hayes        4.0
# 4 2021-11-06     5     Bad Habits                     Ed Sheeran        5.0
#
#    peak-rank  weeks-on-board
# 0          1               3
# 1          1              16
# 2          1              14
# 3          3              19
# 4          2              18

# %%
billboard["date"]
# Out:
# 0        2021-11-06
# 1        2021-11-06
# 2        2021-11-06
# 3        2021-11-06
# 4        2021-11-06
#             ...
# 330082   1958-08-04
# 330083   1958-08-04
# 330084   1958-08-04
# 330085   1958-08-04
# 330086   1958-08-04
# Name: date, Length: 330087, dtype: datetime64[ns]

# %%
pie_chart = billboard["artist"][billboard["song"] == "Please Mr. Postman"].value_counts()

# %%
pie_chart.plot(kind="pie",
               colors=["#6c5ce7", "#00cec9", "#74b9ff"],
               explode=(0, 0, 0.1),
               title="Please Mr. Postman Versions",
               ylabel="artist")
# Out:
# <Axes: title={'center': 'Please Mr. Postman Versions'}, ylabel='artist'>

# %% [markdown]
# ### Pandas Scatter Plots

# %%
houses.plot.scatter(x="bedrooms", y="bathrooms")
# Out:
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %%
houses.plot.scatter(x="bedrooms", y="bathrooms", marker="X")
# Out:
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %% [markdown]
# ### Multiple Plots on the Same Axes

# %%
ufos = pd.read_csv("Data_Analysis/Data/nuforc_reports.csv", parse_dates=["date"])
# Out:
# /tmp/ipykernel_21078/1701521894.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ufos = pd.read_csv("Data_Analysis/Data/nuforc_reports.csv", parse_dates=["date"])

# %%
ufos.head()
# Out:
#      posted      date      time         city state      shape  \
# 0  03/06/23  03/05/23  20:47:00       Villas    NJ    Diamond
# 1  03/06/23  03/05/23  19:00:00  Mooresville    NC        Orb
# 2  03/06/23  03/05/23  12:30:00  Los Angeles    CA   Changing
# 3  03/06/23  03/05/23  00:30:00     Brooklyn    NY      Light
# 4  03/06/23  03/04/23  23:49:00         Enid    OK  Formation
#
#            duration                                            summary images  \
# 0  Few minutes long                                Low flying aircraft    Yes
# 1        10 seconds  Turquoise colored light traveling from south t...    Yes
# 2             4 min               Dark object triangular changed shape    Yes
# 3   Atleast 10 mins    Light object sky, In Brooklyn towards Manhattan    Yes
# 4               NaN  It suddenly appeared over rhe neighbors house ...    Yes
#
#                                             img_link      lat       lng  \
# ...

# %%
ufos["year"] = ufos["date"].dt.year

# %%
ufos[ufos["state"] == "CA"].year.value_counts()
# Out:
# year
# 2022    81
# 2023    17
# 2021     9
# 2020     3
# 2015     3
# 2017     2
# 1980     1
# 2018     1
# Name: count, dtype: int64

# %%
ufos[ufos["state"] == "CA"].year.value_counts().sort_index()
# Out:
# year
# 1980     1
# 2015     3
# 2017     2
# 2018     1
# 2020     3
# 2021     9
# 2022    81
# 2023    17
# Name: count, dtype: int64

# %%
ufos[ufos["state"] == "CA"].year.value_counts().sort_index().plot(label="CA")
ufos[ufos["state"] == "TX"].year.value_counts().sort_index().plot(label="TX")
plt.legend(shadow=True, edgecolor="inherit")
plt.title("UFO Sightings by State")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
ufos[ufos["state"] == "CA"].year.value_counts().sort_index().plot(label="CA")
plt.figure()
ufos[ufos["state"] == "TX"].year.value_counts().sort_index().plot(label="TX")
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ### UFOS Plotting Challenge

# %%
ufos.head()
# Out:
#      posted       date      time         city state      shape  \
# 0  03/06/23 2023-03-05  20:47:00       Villas    NJ    Diamond
# 1  03/06/23 2023-03-05  19:00:00  Mooresville    NC        Orb
# 2  03/06/23 2023-03-05  12:30:00  Los Angeles    CA   Changing
# 3  03/06/23 2023-03-05  00:30:00     Brooklyn    NY      Light
# 4  03/06/23 2023-03-04  23:49:00         Enid    OK  Formation
#
#            duration                                            summary images  \
# 0  Few minutes long                                Low flying aircraft    Yes
# 1        10 seconds  Turquoise colored light traveling from south t...    Yes
# 2             4 min               Dark object triangular changed shape    Yes
# 3   Atleast 10 mins    Light object sky, In Brooklyn towards Manhattan    Yes
# 4               NaN  It suddenly appeared over rhe neighbors house ...    Yes
#
#                                             img_link      lat       lng  \
# ...

# %%
ufos[ufos["shape"]=="Light"].year.value_counts().sort_index().plot()
ufos[ufos["shape"]=="Fireball"].year.value_counts().sort_index().plot()
ufos[ufos["shape"]=="Circle"].year.value_counts().sort_index().plot()
ufos[ufos["shape"]=="Triangle"].year.value_counts().sort_index().plot()
ufos[ufos["shape"]=="Formation"].year.value_counts().sort_index().plot()

plt.xlim(2000,2018)
# Out:
# (2000.0, 2018.0)

# %% [markdown]
# ### Pandas Plotting Challenge

# %%
df = pd.read_csv("Data_Analysis/Data/billboard_charts.csv", parse_dates=["date"])
df.head()
# Out:
#         date  rank           song                         artist  last-week  \
# 0 2021-11-06     1     Easy On Me                          Adele        1.0
# 1 2021-11-06     2           Stay  The Kid LAROI & Justin Bieber        2.0
# 2 2021-11-06     3  Industry Baby        Lil Nas X & Jack Harlow        3.0
# 3 2021-11-06     4     Fancy Like                   Walker Hayes        4.0
# 4 2021-11-06     5     Bad Habits                     Ed Sheeran        5.0
#
#    peak-rank  weeks-on-board
# 0          1               3
# 1          1              16
# 2          1              14
# 3          3              19
# 4          2              18

# %%
new_df = df[df["song"] == "Blinding Lights"].set_index("date")["rank"]
new_df
# Out:
# date
# 2021-09-04    20
# 2021-08-28    21
# 2021-08-21    18
# 2021-08-14    16
# 2021-08-07    17
#               ..
# 2020-01-11    59
# 2020-01-04    72
# 2019-12-28    63
# 2019-12-21    52
# 2019-12-14    11
# Name: rank, Length: 90, dtype: int64

# %%
plt.figure(figsize=(9,5))
new_df.plot(color="#a29bfe", linewidth=3)
plt.gca().invert_yaxis()
plt.xlabel("Date")
plt.title("Blinding Lights Chart Performance")
# Out:
# Text(0.5, 1.0, 'Blinding Lights Chart Performance')

# %% [markdown]
# ### Pandas Automatic Subplots
